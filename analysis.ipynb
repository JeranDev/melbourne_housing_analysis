# %% [markdown]
# # Melbourne Housing Analysis
#
# ⌨ Jeran Burget
#
# Melbourne, Australia's second-largest city, is known for its vibrant cultural scene, diverse population, and beautiful parks. It boasts iconic landmarks like Federation Square and the Royal Botanic Gardens, as well as a thriving coffee culture. Melbourne is famous for its sports passion, hosting events like the Australian Open and Melbourne Cup, making it a dynamic and cosmopolitan destination.
#
# ## Analysis
#
# Recently, the housing market in Melbourne has seen explosive growth. In this analysis, we will conduct an exploratory data analysis to analyze trends in the housing market and try to determine trends that might be useful to an investor.

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv("housing.csv")

# %% [markdown]
# ### Data Exploration

# %%
df.head()
# Out:
#        Suburb          Address  Rooms   Type    Price               Method  \
# 0  Abbotsford  25 Bloomburg St      2  house  1035000        property sold
# 1  Abbotsford     5 Charles St      3  house  1465000  property sold prior
# 2  Abbotsford      55a Park St      4  house  1600000           vendor bid
# 3  Abbotsford     124 Yarra St      3  house  1876000        property sold
# 4  Abbotsford    98 Charles St      2  house  1636000        property sold
#
#   SellerG       Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  Biggin   4/2/2016       2.5      3067         2         1  0.0       156
# 1  Biggin   4/3/2017       2.5      3067         3         2  0.0       134
# 2  Nelson   4/6/2016       2.5      3067         3         1  2.0       120
# 3  Nelson   7/5/2016       2.5      3067         4         2  0.0       245
# 4  Nelson  8/10/2016       2.5      3067         2         1  2.0       256
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6847 entries, 0 to 6846
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         6847 non-null   object
#  1   Address        6847 non-null   object
#  2   Rooms          6847 non-null   int64
#  3   Type           6847 non-null   object
#  4   Price          6847 non-null   int64
#  5   Method         6847 non-null   object
#  6   SellerG        6847 non-null   object
#  7   Date           6847 non-null   object
#  8   Distance       6847 non-null   float64
#  9   Postcode       6847 non-null   int64
#  10  Bedroom2       6847 non-null   int64
#  11  Bathroom       6847 non-null   int64
#  12  Car            6819 non-null   float64
#  13  Landsize       6847 non-null   int64
#  14  BuildingArea   6847 non-null   float64
#  15  YearBuilt      6847 non-null   float64
#  16  CouncilArea    6187 non-null   object
# ...

# %%
df.describe()
# Out:
#              Rooms         Price     Distance     Postcode     Bedroom2  \
# count  6847.000000  6.847000e+03  6847.000000  6847.000000  6847.000000
# mean      2.977070  1.079246e+06    10.124814  3104.269461     2.950343
# std       0.969548  6.732188e+05     5.978374    91.079330     0.969828
# min       1.000000  1.310000e+05     0.000000  3000.000000     0.000000
# 25%       2.000000  6.300000e+05     6.100000  3044.000000     2.000000
# 50%       3.000000  8.925000e+05     9.200000  3083.000000     3.000000
# 75%       4.000000  1.336500e+06    13.000000  3148.000000     4.000000
# max       8.000000  9.000000e+06    47.400000  3977.000000     9.000000
#
#           Bathroom          Car     Landsize  BuildingArea    YearBuilt  \
# count  6847.000000  6819.000000  6847.000000   6847.000000  6847.000000
# mean      1.592814     1.606541   463.281145    142.959226  1964.295312
# std       0.713867     0.944278   569.612425     82.392850    36.691828
# ...

# %% [markdown]
# ### Plot 1: Size of land vs. property cost by property type

# %%
sns.scatterplot(x="Landsize", y="Price", hue="Type", data=df)
plt.show()

# %% [markdown]
# It looks like the "house" type increases in price dramatically as the landsize goes up.

# %% [markdown]
# ### Plot 2: Average price of housing each year

# %%
year_vs_price_df = df.groupby("YearBuilt", as_index=False).agg({"Price": "mean"})
year_vs_price_df
# Out:
#      YearBuilt         Price
# 0       1830.0  8.550000e+05
# 1       1850.0  1.347000e+06
# 2       1854.0  3.310000e+06
# 3       1856.0  2.260000e+06
# 4       1860.0  1.980000e+06
# ..         ...           ...
# 130     2014.0  9.519831e+05
# 131     2015.0  1.255708e+06
# 132     2016.0  1.529026e+06
# 133     2017.0  1.041406e+06
# 134     2018.0  1.310000e+06
#
# [135 rows x 2 columns]

# %% [markdown]
# Using this new dataframe, we can now plot our chart using a line chart.

# %%
sns.lineplot(x="YearBuilt", y="Price", data=year_vs_price_df)
plt.plot()
# Out:
# []

# %% [markdown]
# Interestingly, it looks like as the property becomes newer, the average price decreases.

# %% [markdown]
# ### Plot 3: Average price per region

# %%
region_vs_price_df = df.groupby("Regionname", as_index=False).agg({"Price": "mean"})
region_vs_price_df
# Out:
#                    Regionname         Price
# 0        Eastern Metropolitan  1.118559e+06
# 1            Eastern Victoria  6.813565e+05
# 2       Northern Metropolitan  8.765970e+05
# 3           Northern Victoria  5.694400e+05
# 4  South-Eastern Metropolitan  9.395747e+05
# 5       Southern Metropolitan  1.408658e+06
# 6        Western Metropolitan  8.732954e+05
# 7            Western Victoria  4.081500e+05

# %% [markdown]
# We'll have to make the bar chart bigger to fit all of the text properly.

# %%
plt.figure(figsize=[20, 8])
sns.barplot(x="Regionname", y="Price", data=region_vs_price_df)
plt.plot()
# Out:
# []

# %% [markdown]
# According to the bar chart above, the Southern Metropolitan region has the highest average prices.

# %% [markdown]
# ### Plot 4: Histogram of property prices

# %%
sns.histplot(x="Price", data=df)
plt.plot()
# Out:
# []

# %% [markdown]
# The price is positively scewed. This implied that most houses have lower prices, but there are few individuals with very high prices that stretch the distribution towards the right.

# %% [markdown]
# ### Plot 5: Box plot of properties built in different regions over the years

# %%
sns.boxplot(x="YearBuilt", y="Regionname", data=df)
plt.plot()
# Out:
# []

# %% [markdown]
# The Northern Metropolitan has the widest range of time in terms of properties built. It also looks like the Western Victoria region has built very few properties after the year 2000.

# %% [markdown]
# ### Summary
#
# Here's a summary of the analysis:
#
#     Data Exploration: The analysis begins with exploring the dataset, including examining the first few rows, information about the columns, and descriptive statistics.
#
#     Size of Land vs. Property Cost: A scatter plot is created to visualize the relationship between the size of the land and the cost of the property, with different colors representing different property types. It's observed that the price of houses tends to increase dramatically as the land size increases.
#
#     Average Price of Housing Over the Years: A line plot is used to show the average price of housing each year. Surprisingly, it's found that newer properties tend to have lower average prices compared to older properties.
#
#     Average Price per Region: A bar chart is generated to display the average price of housing in different regions. The Southern Metropolitan region stands out with the highest average prices.
#
#     Distribution of Property Prices: A histogram is plotted to visualize the distribution of property prices. It's observed that the distribution is positively skewed, indicating that most houses have lower prices, but there are few with very high prices that stretch the distribution towards the right.
#
#     Properties Built Over the Years by Region: A box plot is created to show the distribution of properties built in different regions over the years. It's noted that the Northern Metropolitan region has the widest range of years in terms of properties built, and the Western Victoria region has built very few properties after the year 2000.
#
# Overall, the analysis provides insights into various aspects of the Melbourne housing market, including price trends over time, differences between regions, and the distribution of property prices.
